# %% [markdown]
# <a href="https://colab.research.google.com/github/janosv246/MPA-MLF-Project/blob/main/MPA_MLF_Project_balancing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MPA-MLF Project**
#
# Vít Janoš, Kryštof Havrda

# %% [markdown]
# ### 0. Import libraries

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
from google.colab import drive

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.utils.class_weight import compute_class_weight
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.optimizers import AdamW
from keras.optimizers import SGD

# %% [markdown]
# #### 1.1 Set paths

# %%
drive.mount('/content/drive')
BASE_DIR = '/content/drive/MyDrive/data'

TRAIN_DIR = f'{BASE_DIR}/x_train'
TEST_DIR = f'{BASE_DIR}/x_test'
TRAIN_CSV = f'{BASE_DIR}/y_train_v2.csv'
SAMPLE_SUBMISSION_CSV = f'{BASE_DIR}/y_test_submission_example_v2.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### 1.2 Load labels and image paths

# %%
def numeric_file_key(path_obj: Path):
    stem = path_obj.stem
    digits = ''.join(ch for ch in stem if ch.isdigit())
    return int(digits) if digits else stem


def find_id_and_label_columns(df: pd.DataFrame):
    lower_cols = [str(c).strip().lower() for c in df.columns]

    id_candidates = ['id', 'image', 'image_id', 'img_id', 'index']
    label_candidates = ['label', 'labels', 'class', 'target', 'y']

    id_col = None
    label_col = None

    for original, lower in zip(df.columns, lower_cols):
        if lower in id_candidates and id_col is None:
            id_col = original
        if lower in label_candidates and label_col is None:
            label_col = original

    if df.shape[1] == 1:
        label_col = df.columns[0]
        id_col = None
    elif df.shape[1] >= 2:
        if id_col is None:
            id_col = df.columns[0]
        if label_col is None:
            label_col = df.columns[1]

    return id_col, label_col


train_df = pd.read_csv(TRAIN_CSV)
train_id_col, train_label_col = find_id_and_label_columns(train_df)

train_image_paths = sorted(Path(TRAIN_DIR).glob('*.png'), key=numeric_file_key)
print(f'Number of training images: {len(train_image_paths)}')
print('Train CSV columns:', list(train_df.columns))

if train_id_col is None:
    train_labels_df = pd.DataFrame({
        'id': np.arange(1, len(train_df)),
        'label': train_df[train_label_col].to_numpy()
    })
else:
    train_labels_df = train_df[[train_id_col, train_label_col]].copy()
    train_labels_df.columns = ['id', 'label']

train_labels_df = train_labels_df.sort_values('id').reset_index(drop=True)
train_image_ids = np.array([numeric_file_key(p) for p in train_image_paths])

print(train_labels_df.head())
# Out:
# Number of training images: 9227
# Train CSV columns: ['id', 'target']
#    id  label
# 0   0      0
# 1   1      1
# 2   2      0
# 3   3      2
# 4   4      2

# %%
train_df
# Out:
#         id  target
# 0        0       0
# 1        1       1
# 2        2       0
# 3        3       2
# 4        4       2
# ...    ...     ...
# 9222  9222       2
# 9223  9223       3
# 9224  9224       1
# 9225  9225       3
# 9226  9226       0
#
# [9227 rows x 2 columns]

# %% [markdown]
# #### 1.3 Show a few images

# %%
def load_grayscale_image(image_path, target_size=(64, 64)):
    image = Image.open(image_path).convert('L')
    image = image.resize(target_size)
    image = np.array(image, dtype=np.float32) / 255.0
    return image


def display_random_images(image_paths, labels_df, count=8, target_size=(64, 64)):
    selected_idx = np.random.choice(len(image_paths), size=count, replace=False)

    plt.figure(figsize=(16, 6))
    for i, idx in enumerate(selected_idx, 1):
        img_path = image_paths[idx]
        img_id = numeric_file_key(img_path)
        label_row = labels_df.loc[labels_df['id'] == img_id, 'label']
        label = int(label_row.iloc[0]) if len(label_row) > 0 else -1

        img = load_grayscale_image(img_path, target_size=target_size)

        plt.subplot(2, 4, i)
        plt.imshow(img, cmap='gray')
        plt.title(f'id={img_id}, class={label}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()


display_random_images(train_image_paths, train_labels_df)

# %% [markdown]
# #### 1.4 Load and preprocess the dataset

# %%
def build_dataset(image_paths, labels_df=None, target_size=(64, 64)):
    X = []
    y = []
    ids = []

    label_map = None
    if labels_df is not None:
        label_map = dict(zip(labels_df['id'].astype(int), labels_df['label'].astype(int)))

    for img_path in image_paths:
        img_id = int(numeric_file_key(img_path)-1)

        # Skip image if no label exists in label_map
        if label_map is not None and img_id not in label_map:
            continue

        img = load_grayscale_image(img_path, target_size=target_size)
        X.append(img)
        ids.append(img_id)

        if label_map is not None:
            y.append(label_map[img_id])

    X = np.array(X, dtype=np.float32)
    X = X.reshape(-1, target_size[0], target_size[1], 1)
    ids = np.array(ids)

    if label_map is not None:
        y = np.array(y, dtype=np.int32)
        return X, y, ids

    return X, ids


IMG_SIZE = (64, 64)
NUM_CLASSES = 4

X, y, train_ids = build_dataset(train_image_paths, train_labels_df, target_size=IMG_SIZE)
y_cat = to_categorical(y, NUM_CLASSES)

X_train, X_val, y_train, y_val = train_test_split(
    X, y_cat, test_size=0.2, stratify=y
)

print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
print(f'X_train shape: {X_train.shape}')
print(f'X_val shape: {X_val.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_val shape: {y_val.shape}')
print('Classes:', np.unique(y))
# Out:
# X shape: (9227, 64, 64, 1)
# y shape: (9227,)
# X_train shape: (7381, 64, 64, 1)
# X_val shape: (1846, 64, 64, 1)
# y_train shape: (7381, 4)
# y_val shape: (1846, 4)
# Classes: [0 1 2 3]

# %% [markdown]
# ### 2. Build the model

# %% [markdown]
# #### 2.1 Define the model structure

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_60 (Conv2D)              │ (None, 62, 62, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_58 (MaxPooling2D) │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_84 (Dropout)            │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_61 (Conv2D)              │ (None, 29, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_59 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_85 (Dropout)            │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_62 (Conv2D)              │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_60 (MaxPooling2D) │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_86 (Dropout)            │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_26 (Flatten)            │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_87 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,273,604 (4.86 MB)
#  Trainable params: 1,273,604 (4.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 3. Training stage

# %% [markdown]
# #### 3.1 Model training

# %%
epochs = 100
batch_size = 32

model.compile(optimizer=AdamW(learning_rate=0.001, weight_decay=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

y_train_labels = np.argmax(y_train, axis=1)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=y_train_labels
)

class_weight_dict = dict(enumerate(class_weights))
print(class_weight_dict)

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    class_weight=class_weight_dict,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# {0: np.float64(1.5784858853721129), 1: np.float64(0.6091944536150544), 2: np.float64(0.7685339441899208), 3: np.float64(2.3596547314578005)}
# Epoch 1/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.6458 - loss: 0.7563 - val_accuracy: 0.7524 - val_loss: 0.5483
# Epoch 2/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7961 - loss: 0.4297 - val_accuracy: 0.8386 - val_loss: 0.4004
# Epoch 3/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8381 - loss: 0.3599 - val_accuracy: 0.8711 - val_loss: 0.3326
# Epoch 4/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8579 - loss: 0.3159 - val_accuracy: 0.8770 - val_loss: 0.3015
# Epoch 5/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8798 - loss: 0.2627 - val_accuracy: 0.8846 - val_loss: 0.3102
# Epoch 6/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8881 - loss: 0.2523 - val_accuracy: 0.9063 - val_loss: 0.2316
# Epoch 7/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8946 - loss: 0.2283 - val_accuracy: 0.9117 - val_loss: 0.2162
# Epoch 8/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8991 - loss: 0.2189 - val_accuracy: 0.9177 - val_loss: 0.1946
# Epoch 9/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9073 - loss: 0.2067 - val_accuracy: 0.9106 - val_loss: 0.2122
# Epoch 10/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9163 - loss: 0.1936 - val_accuracy: 0.9317 - val_loss: 0.1674
# Epoch 11/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9151 - loss: 0.1864 - val_accuracy: 0.9323 - val_loss: 0.1694
# Epoch 12/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9240 - loss: 0.1628 - val_accuracy: 0.9377 - val_loss: 0.1549
# Epoch 13/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9297 - loss: 0.1636 - val_accuracy: 0.9502 - val_loss: 0.1353
# Epoch 14/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9331 - loss: 0.1570 - val_accuracy: 0.9377 - val_loss: 0.1484
# Epoch 15/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9331 - loss: 0.1475 - val_accuracy: 0.9458 - val_loss: 0.1270
# Epoch 16/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9348 - loss: 0.1428 - val_accuracy: 0.9529 - val_loss: 0.1292
# Epoch 17/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9424 - loss: 0.1293 - val_accuracy: 0.9518 - val_loss: 0.1264
# Epoch 18/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9455 - loss: 0.1254 - val_accuracy: 0.9518 - val_loss: 0.1245
# Epoch 19/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9477 - loss: 0.1229 - val_accuracy: 0.9534 - val_loss: 0.1217
# Epoch 20/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9512 - loss: 0.1173 - val_accuracy: 0.9523 - val_loss: 0.1206
# Epoch 21/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9533 - loss: 0.1083 - val_accuracy: 0.9534 - val_loss: 0.1215
# Epoch 22/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9511 - loss: 0.1120 - val_accuracy: 0.9561 - val_loss: 0.1132
# Epoch 23/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9507 - loss: 0.1114 - val_accuracy: 0.9540 - val_loss: 0.1185
# Epoch 24/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9556 - loss: 0.1057 - val_accuracy: 0.9659 - val_loss: 0.1018
# Epoch 25/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9587 - loss: 0.0988 - val_accuracy: 0.9642 - val_loss: 0.1085
# Epoch 26/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9547 - loss: 0.1076 - val_accuracy: 0.9588 - val_loss: 0.1196
# Epoch 27/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9613 - loss: 0.0920 - val_accuracy: 0.9626 - val_loss: 0.0996
# Epoch 28/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9594 - loss: 0.0897 - val_accuracy: 0.9529 - val_loss: 0.1210
# Epoch 29/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9584 - loss: 0.0963 - val_accuracy: 0.9577 - val_loss: 0.1103
# Epoch 30/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9633 - loss: 0.0815 - val_accuracy: 0.9659 - val_loss: 0.0969
# Epoch 31/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9678 - loss: 0.0806 - val_accuracy: 0.9626 - val_loss: 0.1049
# Epoch 32/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9631 - loss: 0.0836 - val_accuracy: 0.9626 - val_loss: 0.1079
# Epoch 33/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9714 - loss: 0.0682 - val_accuracy: 0.9572 - val_loss: 0.1001
# Epoch 34/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9637 - loss: 0.0796 - val_accuracy: 0.9659 - val_loss: 0.1069
# Epoch 35/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9633 - loss: 0.0800 - val_accuracy: 0.9642 - val_loss: 0.1125
# Epoch 36/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9699 - loss: 0.0693 - val_accuracy: 0.9653 - val_loss: 0.1072
# Epoch 37/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9653 - loss: 0.0827 - val_accuracy: 0.9594 - val_loss: 0.1073
# Epoch 38/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9713 - loss: 0.0671 - val_accuracy: 0.9626 - val_loss: 0.1070
# Epoch 39/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9718 - loss: 0.0711 - val_accuracy: 0.9599 - val_loss: 0.1112
# Epoch 40/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9691 - loss: 0.0689 - val_accuracy: 0.9767 - val_loss: 0.0847
# Epoch 41/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9762 - loss: 0.0531 - val_accuracy: 0.9659 - val_loss: 0.1074
# Epoch 42/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9703 - loss: 0.0689 - val_accuracy: 0.9735 - val_loss: 0.0914
# Epoch 43/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9745 - loss: 0.0628 - val_accuracy: 0.9648 - val_loss: 0.1061
# Epoch 44/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9710 - loss: 0.0653 - val_accuracy: 0.9735 - val_loss: 0.0789
# Epoch 45/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9787 - loss: 0.0562 - val_accuracy: 0.9648 - val_loss: 0.1166
# Epoch 46/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9737 - loss: 0.0612 - val_accuracy: 0.9621 - val_loss: 0.1144
# Epoch 47/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9732 - loss: 0.0593 - val_accuracy: 0.9653 - val_loss: 0.1108
# Epoch 48/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9763 - loss: 0.0590 - val_accuracy: 0.9675 - val_loss: 0.0852
# Epoch 49/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9720 - loss: 0.0720 - val_accuracy: 0.9702 - val_loss: 0.0874
# Epoch 50/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9799 - loss: 0.0526 - val_accuracy: 0.9610 - val_loss: 0.1042
# Epoch 51/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9778 - loss: 0.0540 - val_accuracy: 0.9691 - val_loss: 0.1025
# Epoch 52/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9795 - loss: 0.0505 - val_accuracy: 0.9724 - val_loss: 0.0765
# Epoch 53/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9841 - loss: 0.0378 - val_accuracy: 0.9751 - val_loss: 0.0881
# Epoch 54/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9747 - loss: 0.0659 - val_accuracy: 0.9686 - val_loss: 0.0959
# Epoch 55/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9785 - loss: 0.0517 - val_accuracy: 0.9735 - val_loss: 0.0763
# Epoch 56/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9805 - loss: 0.0467 - val_accuracy: 0.9670 - val_loss: 0.0954
# Epoch 57/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9795 - loss: 0.0493 - val_accuracy: 0.9691 - val_loss: 0.0996
# Epoch 58/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9827 - loss: 0.0371 - val_accuracy: 0.9713 - val_loss: 0.0912
# Epoch 59/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9798 - loss: 0.0466 - val_accuracy: 0.9772 - val_loss: 0.0953
# Epoch 60/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9874 - loss: 0.0309 - val_accuracy: 0.9702 - val_loss: 0.0989
# Epoch 61/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9797 - loss: 0.0546 - val_accuracy: 0.9735 - val_loss: 0.0889
# Epoch 62/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9793 - loss: 0.0511 - val_accuracy: 0.9718 - val_loss: 0.1005
# Epoch 63/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9823 - loss: 0.0433 - val_accuracy: 0.9724 - val_loss: 0.1021
# Epoch 64/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9816 - loss: 0.0465 - val_accuracy: 0.9735 - val_loss: 0.0784
# Epoch 65/100
# 231/231 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9816 - loss: 0.0447 - val_accuracy: 0.9735 - val_loss: 0.0921

# %% [markdown]
# #### 3.2 Plot training history

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Model evaluation

# %%
val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f'Validation Loss: {val_loss:.4f}')
print(f'Validation Accuracy: {val_accuracy:.4f}')

val_pred_prob = model.predict(X_val)
val_pred = np.argmax(val_pred_prob, axis=1)
val_true = np.argmax(y_val, axis=1)

cm = confusion_matrix(val_true, val_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(NUM_CLASSES), yticklabels=range(NUM_CLASSES))
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')
plt.show()

macro_f1 = f1_score(val_true, val_pred, average='macro')
print(f'Macro F1 score: {macro_f1:.4f}')
print(classification_report(val_true, val_pred))
# Out:
# Validation Loss: 0.0763
# Validation Accuracy: 0.9735
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# Macro F1 score: 0.9674
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       293
#            1       0.99      0.97      0.98       757
#            2       0.96      0.98      0.97       601
#            3       0.93      0.91      0.92       195
#
#     accuracy                           0.97      1846
#    macro avg       0.97      0.97      0.97      1846
# weighted avg       0.97      0.97      0.97      1846

# %%
def numeric_file_key(path_obj: Path):
    stem = path_obj.stem
    digits = ''.join(ch for ch in stem if ch.isdigit())
    return int(digits) if digits else stem


def find_id_and_label_columns(df: pd.DataFrame):
    lower_cols = [str(c).strip().lower() for c in df.columns]

    id_candidates = ['id', 'image', 'image_id', 'img_id', 'index']
    label_candidates = ['label', 'labels', 'class', 'target', 'y']

    id_col = None
    label_col = None

    for original, lower in zip(df.columns, lower_cols):
        if lower in id_candidates and id_col is None:
            id_col = original
        if lower in label_candidates and label_col is None:
            label_col = original

    if df.shape[1] == 1:
        label_col = df.columns[0]
        id_col = None
    elif df.shape[1] >= 2:
        if id_col is None:
            id_col = df.columns[0]
        if label_col is None:
            label_col = df.columns[1]

    return id_col, label_col


train_df = pd.read_csv(SAMPLE_SUBMISSION_CSV)
train_id_col, train_label_col = find_id_and_label_columns(train_df)

train_image_paths = sorted(Path(TEST_DIR).glob('*.png'), key=numeric_file_key)
print(f'Number of training images: {len(train_image_paths)}')
print('Train CSV columns:', list(train_df.columns))

if train_id_col is None:
    train_labels_df = pd.DataFrame({
        'id': np.arange(1, len(train_df)),
        'label': train_df[train_label_col].to_numpy()
    })
else:
    train_labels_df = train_df[[train_id_col, train_label_col]].copy()
    train_labels_df.columns = ['id', 'label']

train_labels_df = train_labels_df.sort_values('id').reset_index(drop=True)
train_image_ids = np.array([numeric_file_key(p) for p in train_image_paths])

print(train_labels_df.head())
# Out:
# Number of training images: 3955
# Train CSV columns: ['id', 'target']
#      id  label
# 0  9227      0
# 1  9228      3
# 2  9229      2
# 3  9230      3
# 4  9231      3

# %%
test_image_paths = sorted(Path(TEST_DIR).glob('*.png'), key=numeric_file_key)
print(f'Number of test images: {len(test_image_paths)}')

X_test, test_ids = build_dataset(test_image_paths, labels_df=None, target_size=IMG_SIZE)

print(f'X_test shape: {X_test.shape}')

# Make predictions
test_pred_prob = model.predict(X_test)
test_pred = np.argmax(test_pred_prob, axis=1)

# Create submission DataFrame
submission_df = pd.DataFrame({
    'id': test_ids,
    'target': test_pred
})

# Sort by id to match expected submission format
submission_df = submission_df.sort_values('id').reset_index(drop=True)

print(submission_df.head())

# Save submission file
submission_path = f'{BASE_DIR}/submission.csv'
submission_df.to_csv(submission_path, index=False)
print(f'Submission file saved to {submission_path}')
# Out:
# Number of test images: 3955
# X_test shape: (3955, 64, 64, 1)
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#      id  target
# 0  9227       2
# 1  9228       2
# 2  9229       0
# 3  9230       0
# 4  9231       1
# Submission file saved to /content/drive/MyDrive/data/submission.csv
